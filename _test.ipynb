# %%
import pytk
pytk.check_pytk()
# print(pytk.LLM_APIKEY)

# %%
# pytk.llm_text2text("What is your name?")

# %%
# print(pytk.ocr_file2text("_test/pdf.pdf"))
# print(pytk.ocr_file2text("_test/png.png"))
# print(pytk.ocr_file2text("_test/jpg.jpg"))
# print(pytk.ocr_file2text("_test/jpeg.jpeg"))
# print(pytk.ocr_file2text("_test/txt.txt"))
# print(pytk.ocr_file2text("_test/docx.docx"))
# print(pytk.ocr_file2text("_test/xlsx.xlsx"))
